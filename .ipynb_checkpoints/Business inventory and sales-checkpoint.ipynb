# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %matplotlib inline
df = pd.read_csv("BUSINV.csv")
df.head()
#importing the data
# Out:
#   realtime_start value       date realtime_end
# 0      12/6/2019     .  12/1/1980    12/6/2019
# 1      12/6/2019     .   1/1/1981    12/6/2019
# 2      12/6/2019     .   2/1/1981    12/6/2019
# 3      12/6/2019     .   3/1/1981    12/6/2019
# 4      12/6/2019     .   4/1/1981    12/6/2019

# %%
pd.set_option("display.max_columns", 90)
df.head(-5)
# Out:
#     realtime_start    value       date realtime_end
# 0        12/6/2019        .  12/1/1980    12/6/2019
# 1        12/6/2019        .   1/1/1981    12/6/2019
# 2        12/6/2019        .   2/1/1981    12/6/2019
# 3        12/6/2019        .   3/1/1981    12/6/2019
# 4        12/6/2019        .   4/1/1981    12/6/2019
# ..             ...      ...        ...          ...
# 456      12/6/2019  1993868  12/1/2018    12/6/2019
# 457      12/6/2019  2010849   1/1/2019    12/6/2019
# 458      12/6/2019  2018638   2/1/2019    12/6/2019
# 459      12/6/2019  2018737   3/1/2019    12/6/2019
# 460      12/6/2019  2029828   4/1/2019    12/6/2019
#
# [461 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466 entries, 0 to 465
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   realtime_start  466 non-null    object
#  1   value           466 non-null    object
#  2   date            466 non-null    object
#  3   realtime_end    466 non-null    object
# dtypes: object(4)
# memory usage: 14.7+ KB

# %%
#summary statistics
summary_stats = df[['realtime_start','realtime_end']].describe() 
summary_stats
# Out:
#        realtime_start realtime_end
# count             466          466
# unique              1            1
# top         12/6/2019    12/6/2019
# freq              466          466

# %%
df = pd.read_csv("TOTBUSIMNSA.csv")
df.head()
# Out:
#   realtime_start   value        date realtime_end
# 0     2019-12-06  802948  1992-01-01   2019-12-06
# 1     2019-12-06  809329  1992-02-01   2019-12-06
# 2     2019-12-06  813301  1992-03-01   2019-12-06
# 3     2019-12-06  819247  1992-04-01   2019-12-06
# 4     2019-12-06  815688  1992-05-01   2019-12-06

# %%
# plots of values in businv
fig, axes = plt.subplots(2, 1, figsize=(6, 12))
fig.tight_layout()

# Plot the histogram
sns.histplot(df['value'], ax=axes[0], bins=10)
axes[0].set_title('value')


# Plot the box plot
sns.boxplot(data=df, x='value', ax=axes[1])
axes[1].set_title('Box Plot of value')
# Out:
# C:\Users\BOOK 840\ana\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\BOOK 840\ana\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\BOOK 840\ana\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Box Plot of value')

# %%
df.plot(kind='scatter', x='realtime_end', y='realtime_start', alpha=0.5)
plt.title('realtime_end vs realtime_start')
plt.ylabel('realtime_start')
plt.xlabel('realtime_end')
plt.show()

# %%
#new data on superstore sales
df = pd.read_csv("Superstore.csv", encoding='latin-1')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
summary_stats = df[['Sales','Quantity','Profit']].describe()
summary_stats
# Out:
#               Sales     Quantity       Profit
# count   9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574    28.656896
# std      623.245101     2.225110   234.260108
# min        0.444000     1.000000 -6599.978000
# 25%       17.280000     2.000000     1.728750
# 50%       54.490000     3.000000     8.666500
# 75%      209.940000     5.000000    29.364000
# max    22638.480000    14.000000  8399.976000

# %%
#plots on sales and quantity
fig, axes = plt.subplots(2, 3, figsize=(25, 19))
fig.subplots_adjust(hspace=0.5)

# Plot the histogram for Sales
sns.histplot(df['Sales'], ax=axes[0, 0], bins=10)
axes[0, 0].set_title('Sales')

# Plot the box plot for Sales
sns.boxplot(data=df, x='Sales', ax=axes[0, 1])
axes[0, 1].set_title('Box Plot of Sales')

# Plot the KDE for Sales
sns.kdeplot(data=df, x='Sales', fill=True, ax=axes[0, 2])
axes[0, 2].set_title('KDE of Sales')

# Plot the histogram for Quantity
sns.histplot(df['Quantity'], ax=axes[1, 0], bins=10, color='green')
axes[1, 0].set_title('Quantity')

# Plot the box plot for Quantity
sns.boxplot(data=df, x='Quantity', ax=axes[1, 1], color='green')
axes[1, 1].set_title('Box Plot of Quantity')
# Out:
# C:\Users\BOOK 840\ana\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\BOOK 840\ana\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\BOOK 840\ana\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\BOOK 840\ana\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
df.plot(x='Profit', y='Sales')
 
plt.xlabel('Profit')
plt.ylabel('Sales')
plt.title('Sales vs Profit')

plt.show()

# %%
duplicates = df.duplicated()
duplicates
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Length: 9994, dtype: bool

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df_no_duplicates = df.drop_duplicates()
df_no_duplicates
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df_dropped = df.dropna()
df_dropped
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.plot(x='Ship Date', y='Sales')
 
plt.xlabel('Ship Date')
plt.ylabel('Sales')
plt.title('Sales vs Ship Date')

plt.show()

# %%
df.plot(x='Row ID', y='Sales')
 
plt.xlabel('Row ID')
plt.ylabel('Sales')
plt.title('Sales vs Row ID')

plt.show()
